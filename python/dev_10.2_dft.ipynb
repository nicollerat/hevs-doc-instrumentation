# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

# %%
N=8000
Te=1e-3
f=20.2
time=np.arange(N)*Te
ssin=np.sin(time*2*np.pi*f)

# %%
plt.plot(time,ssin)

# %%
fssin=np.fft.fft(ssin)

# %%
plt.semilogy(np.abs(fssin)/N)
